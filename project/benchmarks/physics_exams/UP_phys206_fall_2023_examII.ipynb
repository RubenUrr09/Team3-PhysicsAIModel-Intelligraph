# %% [markdown]
# # Benchmark I:
#
# ## PHYS 206 FALL 2023 EXAM II Questions + Results from the model
#
# 1. A 10.0-kg block starts from rest and slides down an incline that makes an angle of 29.6°above the horizontal.
# At the end of a horizontal displacement of ∆x = 4.00 m, the block has a speed of 5.00 m/s. The coefficient
# of friction between the block and the incline is µk = 0.250. What is the work done by gravity on the block?
#
# Feedback:
#
# Correct: 222.9J
#
#
# 2. A puck is given an initial velocity v on a horizontal icy surface and the work done by friction as that puck stops
# after traveling a displacement of 5.00 m is Wv. If the puck were given an initial velocity 3v, there is a work done
# by friction W3v on the puck as it stops. What is the ratio W3v/Wv?
#
# Feedback:
#
# Correct: 9
#
#
# 3.  A proton moves directly towards the center of a uranium nucleus which is fixed in position at the origin. At a
# position x0 the kinetic energy of the proton is 9.00 times greater than the potential energy of the system. What
# is the closest position xmin that the proton gets to the nucleus if the potential energy has the form below? For
# this problem treat α as a positive constant and x0 > 0.
# U(x) = α/x
#
# Feedback:
#
# Correct: x_0/10
#
#
# 4.  What is the magnitude of the force on the proton in the previous problem at x = 1.50×10−13 m if α = 2.00×10−26
# Jm?
#
# Feedback:
#
# Correct: 0.889N
#
#
# **NEEDS IMAGE**
# 5. In the picture below there is a 20.0-kg hanging mass connected by a light cable around an ideal pulley to a 45.0-kg
# mass which is on an incline plane. The triangular plane has a horizontal distance 3.00 m and a vertical distance 4.00 m as
# shown in the figure. What does the minimum coefficient of friction have to be so that the masses stay in place? The block is on an incline and the cable attached to the block is parallel to the hypotenuse of the plane, and the pulley has a mass hanging parallel to the vertical axis.
#
# Feedback:
#
# Correct: u = 0.593 when described the image
#
#
# 6. A small 250 g mass is held at rest against a spring that has been compressed by 15.0 cm and has a force constant
# of 300 N/m. When released, the spring pushes the mass which then flies off a table that is 75.0 cm above the
# ground. How far from the edge of the table does the mass hit the ground? Assume that the mass leaves the
# table at the same instant the spring returns to its natural length and that there is no friction between the mass
# and the table
#
# Feedback:
#
# Correct: 2.03m
#
#
# **NEEDS IMAGE**
# 7. On a frictionless table there are three blocks connected by strings. A constant force F is applied to
# the right on the 3 kg block. What is the tension in the string that connects the 2 and 3 kg blocks? Assume the bllock of 1kg is to the left, there's a rope to its right that connects it only to the 2kg block, and there's a rope to the right of the 2kg block that connects it to the 3kg block.
#
# Feedback:
#
# Correct: The model got F/2 when described the image
#
#
# **INPUT MULTIPLE CHOICE ASNWERS TO SEE WHAT IT THINKS
# 8. A block is held at rest compressing a spring on a frictionless incline where the angle of incline is in the range 0 < θ < 90. When released the spring imparts enough energy to the block that it flies off the end of the
# incline. Which of the following best describes the kinetic energy of the block at the peak of its trajectory?
#
# (A) The kinetic energy is equal to the elastic potential energy that was stored in the spring before release.
#
# (B) The kinetic energy is the same as the increase in gravitational potential energy between the release point
# and the peak of the trajectory.
#
# (C) The kinetic energy is the same as the kinetic energy when the block loses contact with the incline.
#
# (D) The kinetic energy is less than the elastic potential energy that was stored in the spring before release but is greater than zero.
#
# (E) The kinetic energy is exactly zero
#
# Feedback:
#
# Correct: D
#
#
# 9. A train is accelerating at a constant rate of 0.500 m/s^2. In one of the cars there is a tennis ball with a mass of
# 57.0 g hanging from a string. This acceleration causes the string to make an angle θ with the vertical. What is the
# work done by tension on the tennis ball as the train moves a displacement of 40.0 m.
#
# Feedback:
#
# Correct (Closest answer): Gave 0J but the answer is 1J
#
# **NEEDS IMAGE**
# 10. A block is suspended from the ceiling by two light ropes as shown below. If the tension in rope 1 is T1 = 30 N,
# what is the tension in rope 2, T2? The angle between the ceiling and T2 is 60 degrees and the angle between T1 and the ceiling is 37 degrees.
#
# Feedback:
#
# Correct: 47.8N when described the image
#
# 11. Three balls A, B and C are thrown from a cliff all with the same initial speed but at different angles. Ball A is
# thrown at 30.0°below the horizontal, ball B is thrown horizontally and ball C is thrown 30.0°above the horizontal.
# Which ball has the greatest kinetic energy just before it hits the ground?
#
# Feedback:
#
# Correct: ALL 3 have the same kinetic energy
#
# 12. A 40,000-kg spacecraft descends vertically near the surface of Planet X. The engines provide a variable upward thrust of the form F(y) = Ay where y is the height above the surface of the planet and y = 0 is the surface of the planet. At a height of 200 m above the surface, the spacecraft is descending at a rate of 15.0 m/s. If the acceleration due to gravity on this planet is 3.92 m/s2, what does the constant A need to be so that the spacecraft reaches the ground the instant it comes to rest? For this problem, solve for the value A by formally applying the work-energy theorem.
#
# Feedback:
#
# Partial Credit: Model got 1343 N/m but it should be 1790 N/m
#
# 13. You drive a car at a constant speed of 100 km/hr around a circular track that has a radius of 200 m. What is
# the minimum coefficient of friction so that the car does not slide?
#
# Feedback:
#
# Correct: u = 0.393
#
# 14.  A box is at rest and stays at rest on a rough incline. As such, there are three forces acting on the box.
# The normal force, FN , the gravitational force Fg and the frictional force Ff . Which force has the largest
# magnitude? Note that the force vectors are only drawn to indicate direction and may not be to scale.
#
# Feedback:
#
# Correct: Model claimed Fg is the largest
#
# 15. A constant force F = 3i − 4j + 2k acts on a 33-kg object as it undergoes a displacement from (−5, 0, 0) to (0, 0, −7). What is the work done on the object by this force? (Note that both the force vector and the positions are given in SI units.)
#
# Feedback:
#
# Correct: 1J
#
# **NEEDS IMAGE**
# 16. The diagram below shows potential energy as a function of position. Which of the statements below correctly identifies the direction of the force at points A and B?
#
# N/A (Can't answer question without the given graph)
#
#
# MODEL SCORE: 14/15 Correct + 1/15 Partial Credit
